# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
cwd = os.getcwd()

# %%
# import data
df = pd.read_excel(cwd + "/Results/angSep_CASCOT__2q_EE.xls", header=None, names=['date', 'angSep_2q_EE'])
df.date=pd.to_datetime(df.date)
df.set_index(['date'],inplace=True)

temp_df=pd.read_excel(cwd + "/Results/angSep_CASCOT__5q_IEUE.xls", header=None, names=['date', 'angSep_5q_IE_UE'])
temp_df.date=pd.to_datetime(temp_df.date)
temp_df.set_index(['date'],inplace=True)

df_new = df.join(temp_df)

temp_df=pd.read_excel(cwd + "/Results/modOfMod_CASCOT__2q_EE.xls", header=None, names=['date', 'modOfMod_2q_EE'])
temp_df.date=pd.to_datetime(temp_df.date)
temp_df.set_index(['date'],inplace=True)

df_new = df_new.join(temp_df)

temp_df=pd.read_excel(cwd + "/Results/modOfMod_CASCOT__5q_IEUE.xls", header=None, names=['date', 'modOfMod_5q_IE_UE'])
temp_df.date=pd.to_datetime(temp_df.date)
temp_df.set_index(['date'],inplace=True)

df_new = df_new.join(temp_df)


temp_df=pd.read_excel(cwd + "/Results/EE_2q.xls", header=None, names=['date', 'EE_2q'])
temp_df.date=pd.to_datetime(temp_df.date)
temp_df.set_index(['date'],inplace=True)

df_new = df_new.join(temp_df)

temp_df=pd.read_excel(cwd + "/Results/IEorUE_5q.xls", header=None, names=['date', 'IEorUE_5q'])
temp_df.date=pd.to_datetime(temp_df.date)
temp_df.set_index(['date'],inplace=True)

df_new = df_new.join(temp_df)

temp_df=pd.read_excel(cwd + "/Results/Aggre_Ur_pct_2q.xls", header=None, names=['date', 'Aggre_Ur_pct_2q'])
temp_df.date=pd.to_datetime(temp_df.date)
temp_df.set_index(['date'],inplace=True)

df_new = df_new.join(temp_df)

df_new
# Out:
#             angSep_2q_EE  angSep_5q_IE_UE  modOfMod_2q_EE  modOfMod_5q_IE_UE  \
# date
# 2001-07-01      0.032588         0.042700        0.023417           0.035414
# 2001-10-01      0.029326         0.037156        0.020187           0.030004
# 2002-01-01      0.030356         0.041659        0.022306           0.031036
# 2002-04-01      0.029384         0.045084        0.022014           0.030064
# 2002-07-01      0.032803         0.038264        0.022669           0.032417
# ...                  ...              ...             ...                ...
# 2019-07-01      0.032366         0.051126        0.028236           0.046408
# 2019-10-01      0.028513         0.040606        0.024713           0.026494
# 2020-01-01      0.027190         0.042402        0.020414           0.033042
# 2020-04-01      0.031035         0.038077        0.026987           0.021652
# 2020-07-01      0.031911         0.049707        0.022482           0.031116
#
#                    EE_2q     IEorUE_5q  Aggre_Ur_pct_2q
# date
# 2001-07-01  2.636275e+07  1.250242e+06         5.375597
# 2001-10-01  2.643149e+07  9.462371e+05         5.095654
# 2002-01-01  2.639837e+07  1.352997e+06         5.251585
# 2002-04-01  2.650777e+07  1.184641e+06         5.050383
# 2002-07-01  2.660488e+07  1.325851e+06         5.584228
# ...                  ...           ...              ...
# 2019-07-01  3.047739e+07  1.493325e+06         4.131078
# 2019-10-01  3.069113e+07  1.050441e+06         3.728245
# 2020-01-01  3.050630e+07  1.076565e+06         4.037277
# 2020-04-01  3.013809e+07  9.970860e+05         4.053965
# 2020-07-01  2.984843e+07  8.573280e+05         5.213281
#
# [76 rows x 7 columns]

# %%
df_new.angSep_2q_EE = df_new.angSep_2q_EE.rolling(5, center=True).mean()
df_new.angSep_5q_IE_UE = df_new.angSep_5q_IE_UE.rolling(5, center=True).mean()
df_new.modOfMod_2q_EE = df_new.modOfMod_2q_EE.rolling(5, center=True).mean()
df_new.modOfMod_5q_IE_UE = df_new.modOfMod_5q_IE_UE.rolling(5, center=True).mean()
df_new.EE_2q = df_new.EE_2q/10000
df_new.IEorUE_5q = df_new.IEorUE_5q/10000
#df_new.Aggre_Ur_pct_2q = df_new.Aggre_Ur_pct_2q.rolling(5, center=True).mean()

# %%
df_new
# Out:
#             angSep_2q_EE  angSep_5q_IE_UE  modOfMod_2q_EE  modOfMod_5q_IE_UE  \
# date
# 2001-07-01           NaN              NaN             NaN                NaN
# 2001-10-01           NaN              NaN             NaN                NaN
# 2002-01-01      0.030891         0.040972        0.022119           0.031787
# 2002-04-01      0.030502         0.040448        0.021833           0.031490
# 2002-07-01      0.030996         0.041097        0.022062           0.032169
# ...                  ...              ...             ...                ...
# 2019-07-01      0.029196         0.046484        0.024348           0.037931
# 2019-10-01      0.029912         0.048606        0.024976           0.037487
# 2020-01-01      0.030203         0.044384        0.024566           0.031742
# 2020-04-01           NaN              NaN             NaN                NaN
# 2020-07-01           NaN              NaN             NaN                NaN
#
#                   EE_2q   IEorUE_5q  Aggre_Ur_pct_2q
# date
# 2001-07-01  2636.275218  125.024229         5.375597
# 2001-10-01  2643.148623   94.623714         5.095654
# 2002-01-01  2639.836764  135.299659         5.251585
# 2002-04-01  2650.776775  118.464128         5.050383
# 2002-07-01  2660.488252  132.585066         5.584228
# ...                 ...         ...              ...
# 2019-07-01  3047.739447  149.332500         4.131078
# 2019-10-01  3069.113200  105.044100         3.728245
# 2020-01-01  3050.630500  107.656500         4.037277
# 2020-04-01  3013.809200   99.708600         4.053965
# 2020-07-01  2984.843200   85.732800         5.213281
#
# [76 rows x 7 columns]

# %%
plt.figure(figsize=(12,5))
plt.xlabel('Date')
plt.ylabel('Mean $\Delta$ Tasks')

ax1 = df_new.angSep_2q_EE.plot(style='k-', label='EE')
ax2 = df_new.angSep_5q_IE_UE.plot(style='k--', label='IE or UE')

h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()


plt.legend(h1, l1, loc=2)
plt.savefig(cwd + '/Figures/meanangSep_EE_IEUE.pdf')

# %%
plt.figure(figsize=(12,5))
plt.xlabel('Date')
plt.ylabel('Mean $\Delta$ Skills')

ax1 = df_new.modOfMod_2q_EE.plot(style='k-', label='EE')
ax2 = df_new.modOfMod_5q_IE_UE.plot(style='k--', label='IE or UE')

h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()


plt.legend(h1, l1, loc=2)
plt.savefig(cwd + '/Figures/meanmodOfMod_EE_IEUE.pdf')

# %%
plt.figure(figsize=(12,5))
plt.xlabel('Date')
plt.ylabel('Workers per quarter (thousands)')

ax1 = df_new.EE_2q.plot(style='k-', label='EE')
#ax2 = df_new.IEorUE_5q.plot(style='k--', label='IE or UE')

h1, l1 = ax1.get_legend_handles_labels()
#h2, l2 = ax2.get_legend_handles_labels()


#plt.legend(h1, l1, loc=2)
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.xlabel('Date')
plt.ylabel('Thousands of workers')


ax1 = df_new.IEorUE_5q.plot(style='k--', label='IE or UE')

h1, l1 = ax1.get_legend_handles_labels()
#h2, l2 = ax2.get_legend_handles_labels()


#plt.legend(h1, l1, loc=2)
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.xlabel('Date')
plt.ylabel('Aggregate Unemployment Rate')


ax1 = df_new.Aggre_Ur_pct_2q.plot(style='k-')

h1, l1 = ax1.get_legend_handles_labels()
#h2, l2 = ax2.get_legend_handles_labels()


#plt.legend(h1, l1, loc=2)
plt.savefig(cwd + '/Figures/Aggre_Ur_pct_2q.pdf')
