# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
cwd = os.getcwd()

# %%
# import data
df = pd.read_excel(cwd + "/Results/angSep_CASCOT__2q_EE.xls", header=None, names=['date', 'angSep_2q_EE'])
df.date=pd.to_datetime(df.date)
df.set_index(['date'],inplace=True)

temp_df=pd.read_excel(cwd + "/Results/angSep_CASCOT__5q_IEUE.xls", header=None, names=['date', 'angSep_5q_IE_UE'])
temp_df.date=pd.to_datetime(temp_df.date)
temp_df.set_index(['date'],inplace=True)

df_new = df.join(temp_df)

temp_df=pd.read_excel(cwd + "/Results/modOfMod_CASCOT__2q_EE.xls", header=None, names=['date', 'modOfMod_2q_EE'])
temp_df.date=pd.to_datetime(temp_df.date)
temp_df.set_index(['date'],inplace=True)

df_new = df_new.join(temp_df)

temp_df=pd.read_excel(cwd + "/Results/modOfMod_CASCOT__5q_IEUE.xls", header=None, names=['date', 'modOfMod_5q_IE_UE'])
temp_df.date=pd.to_datetime(temp_df.date)
temp_df.set_index(['date'],inplace=True)

df_new = df_new.join(temp_df)


temp_df=pd.read_excel(cwd + "/Results/EE_5q.xls", header=None, names=['date', 'EE_2q'])
temp_df.date=pd.to_datetime(temp_df.date)
temp_df.set_index(['date'],inplace=True)

df_new = df_new.join(temp_df)

temp_df=pd.read_excel(cwd + "/Results/IEorUE_5q.xls", header=None, names=['date', 'IEorUE_5q'])
temp_df.date=pd.to_datetime(temp_df.date)
temp_df.set_index(['date'],inplace=True)

df_new = df_new.join(temp_df)

temp_df=pd.read_excel(cwd + "/Results/Aggre_Ur_pct_2q.xls", header=None, names=['date', 'Aggre_Ur_pct_2q'])
temp_df.date=pd.to_datetime(temp_df.date)
temp_df.set_index(['date'],inplace=True)

df_new = df_new.join(temp_df)

df_new
# Out:
#             angSep_2q_EE  angSep_5q_IE_UE  modOfMod_2q_EE  modOfMod_5q_IE_UE  \
# date
# 2000-10-01      0.036387              NaN        0.026132                NaN
# 2001-01-01      0.028077              NaN        0.024437                NaN
# 2001-04-01      0.031524         0.028102        0.024188           0.030423
# 2001-07-01      0.030964         0.054842        0.024852           0.047921
# 2001-10-01      0.033392         0.045391        0.026896           0.038802
# ...                  ...              ...             ...                ...
# 2019-07-01      0.030291         0.051126        0.026545           0.046408
# 2019-10-01      0.033863         0.040606        0.026352           0.026494
# 2020-01-01      0.024934         0.042402        0.018086           0.033042
# 2020-04-01      0.029105         0.038077        0.021983           0.021652
# 2020-07-01      0.031308         0.049707        0.020610           0.031116
#
#                      EE_2q       IEorUE_5q  Aggre_Ur_pct_2q
# date
# 2000-10-01  22665591485440  12055452207104         5.228313
# 2001-01-01  24001346906112  11953619884032         5.335538
# 2001-04-01  24043840088064  12078096581632         5.203001
# 2001-07-01  22417067939840  10606917386240         5.167337
# 2001-10-01  20180055025664  12338460390400         5.318142
# ...                    ...             ...              ...
# 2019-07-01  26579150137856  14933250018304         4.366395
# 2019-10-01  16311699990016  10504410002432         4.198191
# 2020-01-01  17046360008192  10765650015232         4.323305
# 2020-04-01  14721190004736   9970860000768         5.060316
# 2020-07-01  23972390039552   8573280046592         5.085132
#
# [80 rows x 7 columns]

# %%
df_new.angSep_2q_EE = df_new.angSep_2q_EE.rolling(5, center=True).mean()
df_new.angSep_5q_IE_UE = df_new.angSep_5q_IE_UE.rolling(5, center=True).mean()
df_new.modOfMod_2q_EE = df_new.modOfMod_2q_EE.rolling(5, center=True).mean()
df_new.modOfMod_5q_IE_UE = df_new.modOfMod_5q_IE_UE.rolling(5, center=True).mean()
df_new.EE_2q = df_new.EE_2q.rolling(5, center=True).mean()/10000000000
df_new.IEorUE_5q = df_new.IEorUE_5q.rolling(5, center=True).mean()/10000000000
#df_new.Aggre_Ur_pct_2q = df_new.Aggre_Ur_pct_2q.rolling(5, center=True).mean()

# %%
df_new
# Out:
#             angSep_2q_EE  angSep_5q_IE_UE  modOfMod_2q_EE  modOfMod_5q_IE_UE  \
# date
# 2000-10-01           NaN              NaN             NaN                NaN
# 2001-01-01           NaN              NaN             NaN                NaN
# 2001-04-01      0.032069              NaN        0.025301                NaN
# 2001-07-01      0.031372              NaN        0.024998                NaN
# 2001-10-01      0.032166         0.042911        0.025092           0.035762
# ...                  ...              ...             ...                ...
# 2019-07-01      0.029523         0.046484        0.024182           0.037931
# 2019-10-01      0.029792         0.048606        0.023268           0.037487
# 2020-01-01      0.029900         0.044384        0.022715           0.031742
# 2020-04-01           NaN              NaN             NaN                NaN
# 2020-07-01           NaN              NaN             NaN                NaN
#
#                   EE_2q    IEorUE_5q  Aggre_Ur_pct_2q
# date
# 2000-10-01          NaN          NaN         5.228313
# 2001-01-01          NaN          NaN         5.335538
# 2001-04-01  2266.158029  1180.650929         5.203001
# 2001-07-01  2240.339864  1201.157140         5.167337
# 2001-10-01  2278.652020  1207.975738         5.318142
# ...                 ...          ...              ...
# 2019-07-01  1953.463344  1184.902707         4.366395
# 2019-10-01  1880.903374  1191.027850         4.198191
# 2020-01-01  1972.615804  1094.949002         4.323305
# 2020-04-01          NaN          NaN         5.060316
# 2020-07-01          NaN          NaN         5.085132
#
# [80 rows x 7 columns]

# %%
plt.figure(figsize=(12,5))
plt.xlabel('Date')
plt.ylabel('Mean $\Delta$ Tasks')

ax1 = df_new.angSep_2q_EE.plot(style='k-', label='EE')
ax2 = df_new.angSep_5q_IE_UE.plot(style='k--', label='IE or UE')

h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()


plt.legend(h1, l1, loc=2)
plt.savefig(cwd + '/Figures/meanangSep_EE_IEUE.pdf')

# %%
plt.figure(figsize=(12,5))
plt.xlabel('Date')
plt.ylabel('Mean $\Delta$ Skills')

ax1 = df_new.modOfMod_2q_EE.plot(style='k-', label='EE')
ax2 = df_new.modOfMod_5q_IE_UE.plot(style='k--', label='IE or UE')

h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()


plt.legend(h1, l1, loc=2)
plt.savefig(cwd + '/Figures/meanmodOfMod_EE_IEUE.pdf')

# %%
plt.figure(figsize=(12,5))
plt.xlabel('Date')
plt.ylabel('Workers per quarter (thousands)')

ax1 = df_new.EE_2q.plot(style='k-', label='EE')
#ax2 = df_new.IEorUE_5q.plot(style='k--', label='IE or UE')

h1, l1 = ax1.get_legend_handles_labels()
#h2, l2 = ax2.get_legend_handles_labels()


#plt.legend(h1, l1, loc=2)
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.xlabel('Date')
plt.ylabel('Thousands of workers')


ax1 = df_new.IEorUE_5q.plot(style='k--', label='IE or UE')

h1, l1 = ax1.get_legend_handles_labels()
#h2, l2 = ax2.get_legend_handles_labels()


#plt.legend(h1, l1, loc=2)
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.xlabel('Date')
plt.ylabel('Aggregate Unemployment Rate')


ax1 = df_new.Aggre_Ur_pct_2q.plot(style='k-')

h1, l1 = ax1.get_legend_handles_labels()
#h2, l2 = ax2.get_legend_handles_labels()


#plt.legend(h1, l1, loc=2)
plt.savefig(cwd + '/Figures/Aggre_Ur_pct_2q.pdf')

# %%
df_new=pd.read_excel(cwd + "/Results/Hm_data_4_dem.xls", header=None, names=['date', 'occ_Em_4', 'occ_E2E_4', 'occ_Um_4', 'occ_U2E_4', 'occ_Im_4','occ_I2E_4'])
df_new.date=pd.to_datetime(df_new.date)
df_new.set_index(['date'],inplace=True)

# %%
df_new
# Out:
#                 occ_Em_4     occ_E2E_4      occ_Um_4     occ_U2E_4  \
# date
# 2000-10-01  1.833419e+14  1.919933e+14  3.142176e+12  3.142176e+12
# 2001-01-01  1.845219e+14  1.932345e+14  3.547072e+12  3.547072e+12
# 2001-04-01  2.331123e+14  2.443092e+14  3.983709e+12  3.983709e+12
# 2001-07-01  2.585679e+14  2.708424e+14  4.726762e+12  4.726762e+12
# 2001-10-01  2.529734e+14  2.645338e+14  4.458118e+12  4.458118e+12
# ...                  ...           ...           ...           ...
# 2018-10-01  2.913558e+14  3.029488e+14  3.762919e+12  3.762919e+12
# 2019-01-01  2.821362e+14  2.938066e+14  4.249264e+12  4.249264e+12
# 2019-04-01  2.955532e+14  3.065845e+14  3.895099e+12  3.895099e+12
# 2019-07-01  3.161559e+14  3.268079e+14  4.241727e+12  4.241727e+12
# 2019-10-01  3.176993e+14  3.269603e+14  4.314060e+12  4.314060e+12
#
#                 occ_Im_4     occ_I2E_4
# date
# 2000-10-01  3.677182e+12  3.677182e+12
# 2001-01-01  3.153955e+12  3.153955e+12
# 2001-04-01  4.353560e+12  4.353560e+12
# 2001-07-01  5.106736e+12  5.106736e+12
# 2001-10-01  5.032943e+12  5.032943e+12
# ...                  ...           ...
# 2018-10-01  5.919509e+12  5.919509e+12
# 2019-01-01  5.174544e+12  5.174544e+12
# 2019-04-01  5.660756e+12  5.660756e+12
# 2019-07-01  5.424620e+12  5.424620e+12
# 2019-10-01  4.967540e+12  4.967540e+12
#
# [77 rows x 6 columns]

# %%
df_new.occ_Em_4 = df_new.occ_Em_4.rolling(5, center=True).mean()/10000000000
df_new.occ_E2E_4 = df_new.occ_E2E_4.rolling(5, center=True).mean()/10000000000
df_new.occ_Um_4 = df_new.occ_Um_4.rolling(5, center=True).mean()/10000000000
df_new.occ_U2E_4 = df_new.occ_U2E_4.rolling(5, center=True).mean()/10000000000
df_new.occ_Im_4 = df_new.occ_Im_4.rolling(5, center=True).mean()/10000000000
df_new.occ_I2E_4 = df_new.occ_I2E_4.rolling(5, center=True).mean()/10000000000

# %%
plt.figure(figsize=(12,5))
plt.xlabel('Date')
plt.ylabel('y')

ax1 = df_new.occ_Em_4.plot(style='k-', label='EE')
ax2 = ax1.twinx()
ax2 = df_new.occ_Um_4.plot(style='k--', label='UE')
ax3 = df_new.occ_Im_4.plot(style='k.-', label='IE')


h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()
h3, l3 = ax3.get_legend_handles_labels()


#plt.legend(h1, l1, loc=2)
ax1.legend(loc=2)
ax2.legend(loc=1)
plt.plot()
#plt.savefig(cwd + '/Figures/test.pdf')
# Out:
# []
